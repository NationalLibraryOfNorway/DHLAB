# %%
import dhlab.module_update as mu
#mu.update('dhlab_v2')

# %%
import dhlab_v2 as d2
import pandas as pd

# %%
corpus = d2.get_document_corpus(doctype = 'digibok', ddk = "805", limit = 2000)

# %%
corpus
# Out:
#                                    urn    title  \
# 0  URN:NBN:no-nb_digibok_2018041748041  Bagasje
# 1  URN:NBN:no-nb_digibok_2012070408187    Fesjå
# 2  URN:NBN:no-nb_digibok_2018062807128   Arbeid
#
#                            authors                                oaiid  \
# 0                 Rønnestad, Trude  oai:nb.bibsys.no:991501220124702202
# 1                 Sandemose, Aksel  oai:nb.bibsys.no:998730339654702202
# 2  Rønnestad, Trude / Sveen, Karin  oai:nb.bibsys.no:991334820144702202
#
#                             sesamid      isbn10  city timestamp  year  \
# 0  0e1202766613c7e37313c37a812feb00              Oslo      2015  2015
# 1  78a55f860901beafa4574794bdc0853a  8203153402  Oslo      1986  1986
# 2  71646eed92c01f9a7b1919256c040c25              Oslo      2014  2014
#
#    publisher langs                                           subjects  ddc  \
# 0  Gyldendal   nob       antologiar / antologier / norsk / litteratur  805
# 1  Aschehoug   nob                                                     805
# 2  Gyldendal   nob  noveller / antologier / antologiar / norsk / l...  805
#
#   genres   literaryform  doctype
# 0         Uklassifisert  digibok
# 1         Faglitteratur  digibok
# 2         Uklassifisert  digibok

# %%
freqs = d2.get_document_frequencies(list(corpus.urn))

# %%
freqs
# Out:
#              URN:NBN:no-nb_digibok_2014070907108  \
# .                                         3056.0
# ,                                         2305.0
# og                                        1731.0
# i                                         1568.0
# var                                       1175.0
# ...                                          ...
# Debetsaldo                                   NaN
# Kreditsaldo                                  NaN
# Yd                                           NaN
# Cwt                                          NaN
# Qr                                           NaN
#
#              URN:NBN:no-nb_digibok_2014082908063  \
# .                                         1012.0
# ,                                         2149.0
# og                                         732.0
# i                                          421.0
# var                                        445.0
# ...                                          ...
# Debetsaldo                                   NaN
# Kreditsaldo                                  NaN
# Yd                                           NaN
# Cwt                                          NaN
# Qr                                           NaN
#
#              URN:NBN:no-nb_digibok_2010031903022  \
# .                                         3362.0
# ,                                         3511.0
# og                                        1212.0
# i                                         1024.0
# var                                        822.0
# ...                                          ...
# Debetsaldo                                   NaN
# Kreditsaldo                                  NaN
# Yd                                           NaN
# Cwt                                          NaN
# Qr                                           NaN
#
#              URN:NBN:no-nb_digibok_2012110706100  \
# .                                          415.0
# ,                                          297.0
# og                                         204.0
# i                                          156.0
# var                                         14.0
# ...                                          ...
# Debetsaldo                                   NaN
# Kreditsaldo                                  NaN
# Yd                                           NaN
# Cwt                                          NaN
# Qr                                           NaN
#
#              URN:NBN:no-nb_digibok_2011010708017  \
# .                                         1004.0
# ,                                          461.0
# og                                           NaN
# i                                          495.0
# var                                          1.0
# ...                                          ...
# Debetsaldo                                   NaN
# Kreditsaldo                                  NaN
# Yd                                           NaN
# Cwt                                          NaN
# Qr                                           NaN
#
#              URN:NBN:no-nb_digibok_2009112704103  \
# .                                         2415.0
# ,                                         1605.0
# og                                         973.0
# i                                          911.0
# var                                         17.0
# ...                                          ...
# Debetsaldo                                   NaN
# Kreditsaldo                                  NaN
# Yd                                           NaN
# Cwt                                          NaN
# Qr                                           NaN
#
#              URN:NBN:no-nb_digibok_2009111700027  \
# .                                          206.0
# ,                                          160.0
# og                                          50.0
# i                                           30.0
# var                                          NaN
# ...                                          ...
# Debetsaldo                                   NaN
# Kreditsaldo                                  NaN
# Yd                                           NaN
# Cwt                                          NaN
# Qr                                           NaN
#
#              URN:NBN:no-nb_digibok_2007071001024  \
# .                                         5076.0
# ,                                         2165.0
# og                                        1908.0
# i                                         1590.0
# var                                         99.0
# ...                                          ...
# Debetsaldo                                   NaN
# Kreditsaldo                                  NaN
# Yd                                           NaN
# Cwt                                          NaN
# Qr                                           NaN
#
#              URN:NBN:no-nb_digibok_2007051101018  \
# .                                         4153.0
# ,                                         3307.0
# og                                        1748.0
# i                                         1245.0
# var                                        757.0
# ...                                          ...
# Debetsaldo                                   NaN
# Kreditsaldo                                  NaN
# Yd                                           NaN
# Cwt                                          NaN
# Qr                                           NaN
#
#              URN:NBN:no-nb_digibok_2012011208015
# .                                         1837.0
# ,                                          128.0
# og                                           9.0
# i                                           43.0
# var                                          NaN
# ...                                          ...
# Debetsaldo                                  11.0
# Kreditsaldo                                 11.0
# Yd                                          11.0
# Cwt                                         13.0
# Qr                                          14.0
#
# [48002 rows x 10 columns]

# %%
f
# Out:
#                        URN:NBN:no-nb_digibok_2013071008027  \
# $                                                      1.0
# 0,78                                                   1.0
# 0.                                                     1.0
# 000.                                                   1.0
# 02                                                     1.0
# ...                                                    ...
# testosteronproduksjon                                  NaN
# trygghet                                               NaN
# vekttap                                                NaN
# spiser                                                 NaN
# Transparent                                            NaN
#
#                        URN:NBN:no-nb_digibok_2013101806052  \
# $                                                      5.0
# 0,78                                                   NaN
# 0.                                                     NaN
# 000.                                                   NaN
# 02                                                     NaN
# ...                                                    ...
# testosteronproduksjon                                  NaN
# trygghet                                               NaN
# vekttap                                                NaN
# spiser                                                 NaN
# Transparent                                            NaN
#
#                        URN:NBN:no-nb_digibok_2012072408038  \
# $                                                      5.0
# 0,78                                                   NaN
# 0.                                                     NaN
# 000.                                                   1.0
# 02                                                     NaN
# ...                                                    ...
# testosteronproduksjon                                  NaN
# trygghet                                               NaN
# vekttap                                                NaN
# spiser                                                 NaN
# Transparent                                            NaN
#
#                        URN:NBN:no-nb_digibok_2016052308143  \
# $                                                      NaN
# 0,78                                                   NaN
# 0.                                                     NaN
# 000.                                                   NaN
# 02                                                     NaN
# ...                                                    ...
# testosteronproduksjon                                  NaN
# trygghet                                               NaN
# vekttap                                                NaN
# spiser                                                 NaN
# Transparent                                            NaN
#
#                        URN:NBN:no-nb_digibok_2014121708203  \
# $                                                      NaN
# 0,78                                                   NaN
# 0.                                                     NaN
# 000.                                                   NaN
# 02                                                     NaN
# ...                                                    ...
# testosteronproduksjon                                  NaN
# trygghet                                               NaN
# vekttap                                                NaN
# spiser                                                 NaN
# Transparent                                            NaN
#
#                        URN:NBN:no-nb_digibok_2016100609088  \
# $                                                      NaN
# 0,78                                                   NaN
# 0.                                                     NaN
# 000.                                                   NaN
# 02                                                     2.0
# ...                                                    ...
# testosteronproduksjon                                  NaN
# trygghet                                               NaN
# vekttap                                                NaN
# spiser                                                 NaN
# Transparent                                            NaN
#
#                        URN:NBN:no-nb_digibok_2012012705005  \
# $                                                      NaN
# 0,78                                                   NaN
# 0.                                                     2.0
# 000.                                                   1.0
# 02                                                     NaN
# ...                                                    ...
# testosteronproduksjon                                  NaN
# trygghet                                               NaN
# vekttap                                                NaN
# spiser                                                 NaN
# Transparent                                            NaN
#
#                        URN:NBN:no-nb_digibok_2020071448643  \
# $                                                      NaN
# 0,78                                                   NaN
# 0.                                                     NaN
# 000.                                                   NaN
# 02                                                     NaN
# ...                                                    ...
# testosteronproduksjon                                  NaN
# trygghet                                               NaN
# vekttap                                                NaN
# spiser                                                 NaN
# Transparent                                            NaN
#
#                        URN:NBN:no-nb_digibok_2008040200099  \
# $                                                      NaN
# 0,78                                                   NaN
# 0.                                                     1.0
# 000.                                                   NaN
# 02                                                     NaN
# ...                                                    ...
# testosteronproduksjon                                  NaN
# trygghet                                               NaN
# vekttap                                                NaN
# spiser                                                 NaN
# Transparent                                            NaN
#
#                        URN:NBN:no-nb_digibok_2010082703006
# $                                                      NaN
# 0,78                                                   NaN
# 0.                                                     NaN
# 000.                                                   NaN
# 02                                                     NaN
# ...                                                    ...
# testosteronproduksjon                                  2.0
# trygghet                                               2.0
# vekttap                                                2.0
# spiser                                                 4.0
# Transparent                                           21.0
#
# [42235 rows x 10 columns]

# %%
words = f.sort_values(by = f.columns[0]).head(100000).index
len(words)
# Out:
# 42235

# %%
# %%time
d2.ngram_book(word = words, period = (1950, 1960)).transpose().sort_values(by = '1950', ascending = False)
# Out:
# Wall time: 1.96 s
#                  1950      1951      1952      1953      1954      1955  \
# —           1321193.0  772179.0  846710.0  801107.0  882687.0  796748.0
# I            371703.0  244444.0  259516.0  248395.0  388214.0  366149.0
# f            276138.0  160578.0  185593.0  167909.0  184606.0  165416.0
# '            259059.0  180284.0  161680.0  192447.0  258434.0  245079.0
# Vi           115312.0   75889.0   79158.0   80121.0   83429.0   82941.0
# ...               ...       ...       ...       ...       ...       ...
# trade-off         NaN       NaN       NaN       NaN       NaN       NaN
# trivially         NaN       1.0       1.0       NaN       NaN       NaN
# vindicates        NaN       NaN       2.0       NaN       NaN       NaN
# yif               NaN       1.0       1.0       NaN       NaN       9.0
# Øiolf             NaN       NaN       NaN       2.0       NaN       1.0
#
#                 1956       1957       1958       1959       1960
# —           944091.0  1067140.0  1159507.0  1033445.0  1099948.0
# I           370385.0   430477.0   404299.0   337686.0   439677.0
# f           353586.0   379234.0   319518.0   234566.0   181497.0
# '           256745.0   267520.0   319079.0   270798.0   285222.0
# Vi           78780.0    86242.0    97449.0    96006.0   120385.0
# ...              ...        ...        ...        ...        ...
# trade-off        NaN        NaN        NaN        7.0        NaN
# trivially        NaN        NaN        NaN        NaN        NaN
# vindicates       NaN        NaN        NaN        NaN        NaN
# yif              NaN        1.0        6.0        NaN        1.0
# Øiolf            NaN        NaN        NaN        NaN        NaN
#
# [951 rows x 11 columns]
